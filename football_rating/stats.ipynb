# %%
import matplotlib.pyplot as plt
import statistics

# %%
data = [2302, 2000, 1830, 1784, 1745, 1709, 1597, 1536, 1482, 1463, 1450, 1433, 1392, 1389, 1387, 1383, 1372, 1358, 1283, 1274, 1271, 1266, 1250, 1240, 1223, 1223, 1214, 1197, 1196, 1187, 1183, 1171, 1168, 1158, 1112, 1104, 1101, 1098, 1089, 1068, 1061, 1039, 1025, 1023, 1018, 1016, 1013, 983, 965, 941, 923, 834, 715]

# %%
plt.hist(data)
plt.show()

# %%
statistics.mean(data)
# Out:
# 1268.754716981132
